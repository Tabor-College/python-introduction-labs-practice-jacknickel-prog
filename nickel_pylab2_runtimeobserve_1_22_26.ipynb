# %%
"""
File: nickel_pylab2_runtimeobserve_1-22-26.ipynb
Author: Jack Nickel
Date: 1-22-2026
Purpose: To predict and observe Python execution for lab 2.
"""

# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %% [markdown]
# What prints first? What prints last?
# - I predicted that "A" would print first and "B" would print last.
# - My prediction was correct, "A" printed first and "B" printed last.

# %%
x = 10
y = x
x = 20
print(y)
# Out:
# 10

# %% [markdown]
# What number is printed?
# - Prediction: 10 will be printed
# - Result: 10 was printed

# %%
x = 5
x = x + 1
print(x)
# Out:
# 6

# %% [markdown]
# What is printed?
# - Prediction: 6 will be printed.
# - Result: 6 was printed.

# %%
def add(a,b):
  print("inside")
  return a + b

print("before")
add(2,3)
print("after")
# Out:
# before
# inside
# after

# %% [markdown]
# In what order do the words print?
# - Prediction: I predicted the words would print in order: "before", "inside", and then "after".
# - Result: My prediction was correct. "before" printed first. "inside" printed second. "after" printed last.

# %%
def make():
  x = [1,2]
  return x

lst = make()
print(lst)
# Out:
# [1, 2]

# %% [markdown]
# Does this print something or crash?
# - Prediction: It will print [1,2]
# - Result: It did print [1,2]

# %%
lst = [1,2]
lst.append(3)
print(lst)

lst = [1,2]
lst = [9,10]
print(lst)
# Out:
# [1, 2, 3]
# [9, 10]

# %% [markdown]
# What prints in each case?
# - Prediction: I predicted the first case would print [1,2,3] and the second case would print [9,10]
# - Result: The first case printed [1,2,3] and the second case printed [9,10]

# %%
def f(x):
  x = x + 1

a = 10
f(a)
print(a)
# Out:
# 10

# %% [markdown]
# What number prints?
# - Prediction: I predicted it would print the number 10.
# - Result: It printed the number 10

# %%
for i in [1,2,3]:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# How many lines print?
# - Prediction: I predicted 3 lines would print.
# - Result: 3 lines printed.

# %%
it = iter([1,2])
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-10269813.py in <cell line: 0>()
#       2 print(next(it))
#       3 print(next(it))
# ----> 4 print(next(it))
#
# StopIteration:

# %% [markdown]
# Does the last line print a value or cause an error?
# - Prediction: The last line will print an error.
# - Result: The last line did print an error.

# %%
def demo():
  print("A")
  yield 1
  print("B")

x = demo()

# %% [markdown]
# Is anything printed yet? Yes or no.
# - Prediction: No
# - Result: No

# %%
g = demo()
print(next(g))
print(next(g))
# Out:
# A
# 1
# B
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-3130011051.py in <cell line: 0>()
#       1 g = demo()
#       2 print(next(g))
# ----> 3 print(next(g))
#
# StopIteration:

# %% [markdown]
# Which letters print, and in what order?
# - Prediction: I predicted the "A" would be printed first, followed by the "B".
# - Result: My prediction was correct, however; a 1 printed between the "A" and "B". There was also an error afterward.

# %%
def outer():
  x = 10
  def inner():
    return x
  return inner

f = outer()
print(f())
# Out:
# 10

# %% [markdown]
# Does this print a number or crash?
# - Prediction: I predicted it would crash.
# - Result: My prediction was wrong, it printed 10.

# %%
def deco(fn):
  def wrapper():
    print("before")
    fn()
    print("after")
  return wrapper

@deco
def hello():
  print("hello")

hello()
# Out:
# before
# hello
# after

# %% [markdown]
# How many lines print?
# - Prediction: I predicted 1 line would print
# - Result: 3 lines printed

# %%
class A:
  x = 10

a = A()
print(a.x)
# Out:
# 10

# %% [markdown]
# Does this print a number or raise an error?
# - Prediction: It will print the number 10.
# - Result: It printed the number 10

# %%
class MyRange:
  def __iter__(self):
    return self
  def __next__(self):
    raise StopIteration

for x in MyRange():
  print(x)

# %% [markdown]
# Does this run or crash?
# - Prediction: I predicted it would crash.
# - Result: It ran without errors or output.
